# %% [markdown]
# # 00. Setup and the image-processing workflow
#
# **Author:** Md. Mobarak Karim, Ph.D.
# **Level:** Beginner
# **Estimated study time:** 30–60 minutes
#
# ## What you will learn
# - Verify the Python environment
# - Understand the course workflow
# - Inspect a first image
#
# > **Course habit:** run one cell at a time, inspect the result, and change one parameter before moving on.

# %% [markdown]
# ## Why start here?
#
# Image processing becomes much easier when your Python environment is predictable. The workflow used throughout this course is:
#
# **load → inspect → process → visualize → measure → save**

# %%
import sys
import numpy as np
import matplotlib
import skimage
import pandas as pd
import imageio

print('Python:', sys.version.split()[0])
print('NumPy:', np.__version__)
print('Matplotlib:', matplotlib.__version__)
print('scikit-image:', skimage.__version__)
print('pandas:', pd.__version__)
print('imageio:', imageio.__version__)

# %% [markdown]
# ## A first image in five lines
#
# `scikit-image` represents images as NumPy arrays. That is the central idea of the entire course.

# %%
from skimage import data
import matplotlib.pyplot as plt

image = data.camera()
print('shape:', image.shape)
print('dtype:', image.dtype)
print('intensity range:', image.min(), 'to', image.max())

plt.imshow(image, cmap='gray')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Recommended project folder
#
# ```text
# project/
# ├── notebooks/
# ├── data/
# │   ├── raw/
# │   └── processed/
# ├── outputs/
# └── README.md
# ```
#
# **Rule:** do not overwrite your original microscopy or camera files while experimenting.
#
# ## Exercise
# Change `data.camera()` to `data.coins()` and compare `shape`, `dtype`, and intensity range.
